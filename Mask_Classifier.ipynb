# %% [markdown]
# # Setting

# %%
import os
import glob
import math
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from PIL import Image
from tqdm.auto import tqdm
import random as r
import wandb
from collections import Counter

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from torchvision import transforms
from efficientnet_pytorch import EfficientNet
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# Seed the behavior of the environment variable
os.environ['PYTHONHASHSEED'] = str(1)
# Seed numpy's instance in case you are using numpy's random number generator, shuffling operations, ...
np.random.seed(1)
# Seed Python's random number generator, in case you are using Python's random number generator, shuffling operations, ...
r.seed(1)

# %%
wandb.init(project='mask_classification', entity='sala0320', reinit=True)
config = wandb.config

# %%
BASE_MASK_PATH = '/opt/ml/input/data/'
TRAIN_MASK_IMAGE_PATH = os.path.join(BASE_MASK_PATH, 'train/images/')
TRAIN_MASK_LABEL_PATH = os.path.join(BASE_MASK_PATH, 'train/train.csv')
TEST_MASK_IMAGE_PATH = os.path.join(BASE_MASK_PATH, 'test/images/')
TEST_MASK_LABEL_PATH = os.path.join(BASE_MASK_PATH, 'test/info.csv')

# %%
train_data = pd.read_csv('/opt/ml/input/data/train/train.csv')
train_pre_data = pd.read_csv('/opt/ml/input/data/train/train_pre.csv')
train_pre_data['gender'] = train_pre_data['gender'].map({'male':0, 'female':1})
train_pre_data.head()
# Out:
#        id  gender   race  age                                       path  \
# 0  000001       1  Asian   45          000001_female_Asian_45/normal.jpg
# 1  000001       1  Asian   45  000001_female_Asian_45/incorrect_mask.jpg
# 2  000001       1  Asian   45           000001_female_Asian_45/mask1.jpg
# 3  000001       1  Asian   45           000001_female_Asian_45/mask2.jpg
# 4  000001       1  Asian   45           000001_female_Asian_45/mask3.jpg
#
#    class
# 0     16
# 1     10
# 2      4
# 3      4
# 4      4

# %% [markdown]
# # Data

# %% [markdown]
# ## Dataset

# %%
img_path = train_pre_data['path']
labels = train_pre_data['class']

# %%
class TrainDataset(Dataset):
    def __init__(self, img_paths, labels, transform):
        self.img_paths = TRAIN_MASK_IMAGE_PATH + img_paths
        self.labels = labels
        self.transform = transform

    def __getitem__(self, idx):
        x = Image.open(self.img_paths[idx])
        y = self.labels[idx]
  
        if self.transform:
            x = self.transform(x)
        
        return x, y
        
    def __len__(self):
        return len(self.img_paths)

# %%
# train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(img_path, labels, test_size=0.2, stratify=labels, shuffle=True, random_state=30)
x_train = x_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
x_valid = x_valid.reset_index(drop=True)
y_valid = y_valid.reset_index(drop=True)

# %%
#transform
train_transform = transforms.Compose([ 
    # transforms.Resize((380,380)),
    transforms.CenterCrop(380),
    # transforms.GaussianBlur(11),
    # transforms.RandomAutocontrast(p=0.5),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(), 
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

valid_transform = transforms.Compose([
    transforms.CenterCrop(380),
    transforms.ToTensor(), 
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
mask_train_dataset = TrainDataset(x_train, y_train, train_transform)
mask_valid_dataset = TrainDataset(x_valid, y_valid, valid_transform)

# %%
from albumentations import *
from albumentations.pytorch import ToTensorV2

# %% [markdown]
# ## DataLoader

# %%
from multiprocessing import cpu_count
num_workers = int(cpu_count() / 2)
batch_size = 32

mask_train_dataloader = DataLoader(
    mask_train_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
    num_workers=num_workers
    )

mask_valid_dataloader = DataLoader(
    mask_valid_dataset,
    batch_size=batch_size,
    )

# %%
images, labels = next(iter(mask_train_dataloader))
labels
# Out:
# tensor([ 4,  4, 14,  4, 16,  4,  3,  3,  3,  4,  4,  6,  4,  0,  4, 12,  4,  0,
#          0,  4,  4,  1,  3,  3,  0,  3,  3,  4,  3, 16,  0,  0])

# %% [markdown]
# # Modeling

# %%
efficient = EfficientNet.from_pretrained('efficientnet-b4')
for param in efficient.parameters():
    param.requires_grad = False
efficient._fc = torch.nn.Linear(in_features=1792, out_features=18, bias=True)

# torch.nn.init.xavier_uniform_(efficient._fc.weight)
# stdv = 1. / math.sqrt(efficient._fc.weight.size(1))
# efficient._fc.bias.data.uniform_(-stdv, stdv)

model = efficient
model
# Out:
# Loaded pretrained weights for efficientnet-b4
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 48, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   )
#   (_bn0): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         48, 48, kernel_size=(3, 3), stride=[1, 1], groups=48, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         48, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         24, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 24, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(5, 5), stride=[2, 2], groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(5, 5), stride=(1, 1), groups=336, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(5, 5), stride=(1, 1), groups=336, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(5, 5), stride=(1, 1), groups=336, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(3, 3), stride=[2, 2], groups=336, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=[1, 1], groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=[2, 2], groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (23): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (24): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (25): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (26): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (27): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (28): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (29): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (30): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(3, 3), stride=[1, 1], groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 448, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(448, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (31): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         448, 2688, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2688, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2688, 2688, kernel_size=(3, 3), stride=(1, 1), groups=2688, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2688, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2688, 112, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         112, 2688, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2688, 448, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(448, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     448, 1792, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1792, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.4, inplace=False)
#   (_fc): Linear(in_features=1792, out_features=18, bias=True)
#   (_swish): MemoryEfficientSwish()
# )

# %% [markdown]
# # Train

# %%
class FocalLoss(nn.Module):

    def __init__(self, gamma=0, eps=1e-7):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        #print(self.gamma)
        self.eps = eps
        self.ce = torch.nn.CrossEntropyLoss(reduction="none")

    def forward(self, input, target):
        logp = self.ce(input, target)
        p = torch.exp(-logp)
        loss = (1 - p) ** self.gamma * logp
        return loss.mean()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # 학습 때 GPU 사용여부 결정. Colab에서는 "런타임"->"런타임 유형 변경"에서 "GPU"를 선택할 수 있음

print(f"{device} is using!")

model.to(device)

LEARNING_RATE = 0.0001 # 학습 때 사용하는 optimizer의 학습률 옵션 설정
NUM_EPOCH = 20 # 학습 때 mnist train 데이터 셋을 얼마나 많이 학습할지 결정하는 옵션. 여러 값을 사용해보세요1

loss_fn = torch.nn.CrossEntropyLoss()
# loss_fn = FocalLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# scheduler = optim.lr_scheduler.LambdaLR(optimizer=optimizer,
#                                 lr_lambda=lambda epoch: 0.95 ** epoch,
#                                 last_epoch=-1,
#                                 verbose=False)
# config = wandb.config
# config.learning_rate = LEARNING_RATE

dataloaders = {
    "train" : mask_train_dataloader,
    "valid" : mask_valid_dataloader
}
# Out:
# cuda:0 is using!

# %%
### 학습 코드 시작
best_test_accuracy = 0.
best_test_loss = 0.
# early_stopping = 0.

for epoch in range(NUM_EPOCH):
  for phase in ["train", "valid"]:
    running_loss = 0.
    running_acc = 0.
    running_f1 = 0.

    if phase == "train":
      model.train() 
      # 네트워크 모델을 train 모드로 두어 gradient을 계산하고, 여러 sub module (배치 정규화, 드롭아웃 등)이 train mode로 작동할 수 있도록 함
    elif phase == "valid":
      model.eval() 
      # 네트워크 모델을 eval 모드 두어 여러 sub module들이 eval mode로 작동할 수 있게 함
  
    for ind, (images, labels) in enumerate(tqdm(dataloaders[phase])):

      images = images.to(device)
      labels = labels.to(device)
      optimizer.zero_grad() # parameter gradient를 업데이트 전 초기화함

      with torch.set_grad_enabled(phase == "train"): # train 모드일 시에는 gradient를 계산하고, 아닐 때는 gradient를 계산하지 않아 연산량 최소화
        logits = model(images)
        _, preds = torch.max(logits, 1) # 모델에서 linear 값으로 나오는 예측 값 ([0.9,1.2, 3.2,0.1,-0.1,...])을 최대 output index를 찾아 예측 레이블([2])로 변경함  
        loss = loss_fn(logits, labels)

        if phase == "train":
          loss.backward() # 모델의 예측 값과 실제 값의 CrossEntropy 차이를 통해 gradient 계산
          optimizer.step() # 계산된 gradient를 가지고 모델 업데이트
          # scheduler.step() 

      running_loss += loss.item() * images.size(0) # 한 Batch에서의 loss 값 저장
      running_acc += torch.sum(preds == labels.data) # 한 Batch에서의 Accuracy 값 저장
      running_f1 += f1_score(preds.cpu().numpy(), labels.cpu().numpy(), average='macro')
      
    # 한 epoch이 모두 종료되었을 때,
    epoch_loss = running_loss / len(dataloaders[phase].dataset)
    epoch_acc = running_acc / len(dataloaders[phase].dataset)
    wandb.log({"epoch_loss":  epoch_loss.item()})
    wandb.log({"epoch_acc":  epoch_acc.item()})

    print(f"현재 epoch-{epoch}의 {phase}-데이터 셋에서 평균 Loss : {epoch_loss:.3f}, 평균 Accuracy : {epoch_acc:.3f}")

    if phase == "valid" and best_test_accuracy < epoch_acc: # phase가 test일 때, best accuracy 계산
      best_test_accuracy = epoch_acc

    if phase == "valid" and best_test_loss < epoch_loss: # phase가 test일 때, best loss 계산
      best_test_loss = epoch_loss
      torch.save(model.state_dict(), '/opt/ml/input/data/train/best_model.pth')
      
    # else:
    #   early_stopping += 1
    #   print("Early stopping! " + str(early_stopping))
    #   if early_stopping >=5:
    #     break

    
print("학습 종료!")
print(f"최고 accuracy : {best_test_accuracy}, 최고 낮은 loss : {best_test_loss}")

# %% [markdown]
# # Testing

# %%
model = EfficientNet.from_pretrained('efficientnet-b4')
model._fc = torch.nn.Linear(in_features=1792, out_features=18, bias=True)
model.load_state_dict(torch.load('/opt/ml/input/data/train/best_model.pth'))
model
# Out:
# Loaded pretrained weights for efficientnet-b4
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 48, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   )
#   (_bn0): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         48, 48, kernel_size=(3, 3), stride=[1, 1], groups=48, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         48, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         24, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 24, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(5, 5), stride=[2, 2], groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(5, 5), stride=(1, 1), groups=336, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(5, 5), stride=(1, 1), groups=336, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(5, 5), stride=(1, 1), groups=336, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(3, 3), stride=[2, 2], groups=336, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=[1, 1], groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=[2, 2], groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (23): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (24): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (25): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (26): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (27): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (28): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (29): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (30): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(3, 3), stride=[1, 1], groups=1632, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 448, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(448, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (31): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         448, 2688, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2688, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2688, 2688, kernel_size=(3, 3), stride=(1, 1), groups=2688, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2688, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2688, 112, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         112, 2688, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2688, 448, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(448, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     448, 1792, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1792, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.4, inplace=False)
#   (_fc): Linear(in_features=1792, out_features=18, bias=True)
#   (_swish): MemoryEfficientSwish()
# )

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
class TestDataset(Dataset):
    def __init__(self, img_paths, transform):
        self.img_paths = TRAIN_MASK_IMAGE_PATH + img_paths
        self.transform = transform

    def __getitem__(self, index):
        image = Image.open(self.img_paths[index])

        if self.transform:
            image = self.transform(image)
        return image

    def __len__(self):
        return len(self.img_paths)

# %%
# Test Dataset 클래스 객체를 생성하고 DataLoader를 만듭니다.
image_paths = train_pre_data['path']
transform = transforms.Compose([
    transforms.CenterCrop(380),
    # Resize((380, 380), Image.BILINEAR),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.2, 0.2, 0.2)),
])
dataset = TestDataset(image_paths, transform)

loader = DataLoader(
    dataset,
    shuffle=False
)

# 모델을 정의합니다. (학습한 모델이 있다면 torch.load로 모델을 불러주세요!)
device = torch.device('cuda')
# model = MyModel(num_classes=18).to(device)
model = model.to(device)
model.eval()

# 모델이 테스트 데이터셋을 예측하고 결과를 저장합니다.
all_predictions = []
for images in loader:
    with torch.no_grad():
        images = images.to(device)
        pred = model(images)
        pred = pred.argmax(dim=-1)
        all_predictions.extend(pred.cpu().numpy())

# %%
test_pre_data = train_pre_data
test_pre_data['predict'] = all_predictions
for i in range(len(test_pre_data)):
    if test_pre_data['class'][i] != test_pre_data['predict'][i]:
        print(f"path : {test_pre_data['path'][i]} real : {test_pre_data['class'][i]} predict : {test_pre_data['predict'][i]}")
# Out:
# path : 000001_female_Asian_45/incorrect_mask.jpg real : 10 predict : 4
# path : 000001_female_Asian_45/mask1.jpg real : 4 predict : 3
# path : 000001_female_Asian_45/mask2.jpg real : 4 predict : 3
# path : 000002_female_Asian_52/normal.jpg real : 16 predict : 4
# path : 000002_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000004_male_Asian_54/incorrect_mask.jpg real : 7 predict : 4
# path : 000004_male_Asian_54/mask1.jpg real : 1 predict : 4
# path : 000004_male_Asian_54/mask2.jpg real : 1 predict : 4
# path : 000004_male_Asian_54/mask3.jpg real : 1 predict : 4
# path : 000004_male_Asian_54/mask4.jpg real : 1 predict : 4
# path : 000004_male_Asian_54/mask5.jpg real : 1 predict : 4
# path : 000005_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000006_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000007_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000008_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000009_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000010_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000012_male_Asian_57/normal.jpg real : 13 predict : 16
# path : 000012_male_Asian_57/incorrect_mask.jpg real : 7 predict : 1
# path : 000012_male_Asian_57/mask5.jpg real : 1 predict : 4
# path : 000014_female_Asian_58/mask1.jpg real : 4 predict : 3
# path : 000014_female_Asian_58/mask4.jpg real : 4 predict : 17
# path : 000015_male_Asian_55/normal.jpg real : 13 predict : 16
# path : 000015_male_Asian_55/incorrect_mask.jpg real : 7 predict : 4
# path : 000015_male_Asian_55/mask1.jpg real : 1 predict : 3
# path : 000015_male_Asian_55/mask5.jpg real : 1 predict : 4
# path : 000016_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000018_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000019_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000019_female_Asian_57/mask3.jpg real : 4 predict : 3
# path : 000020_female_Asian_50/normal.jpg real : 16 predict : 4
# path : 000020_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000020_female_Asian_50/mask3.jpg real : 4 predict : 3
# path : 000021_female_Asian_54/normal.jpg real : 16 predict : 12
# path : 000021_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000021_female_Asian_54/mask4.jpg real : 4 predict : 17
# path : 000022_female_Asian_58/normal.jpg real : 16 predict : 17
# path : 000023_female_Asian_55/normal.jpg real : 16 predict : 12
# path : 000023_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000024_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000024_female_Asian_58/mask1.jpg real : 4 predict : 3
# path : 000025_female_Asian_49/incorrect_mask.jpg real : 10 predict : 4
# path : 000026_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000028_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000028_female_Asian_58/mask1.jpg real : 4 predict : 15
# path : 000029_female_Asian_58/normal.jpg real : 16 predict : 4
# path : 000029_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000030_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000031_female_Asian_54/mask3.jpg real : 4 predict : 17
# path : 000033_male_Asian_57/incorrect_mask.jpg real : 7 predict : 1
# path : 000033_male_Asian_57/mask1.jpg real : 1 predict : 3
# path : 000033_male_Asian_57/mask2.jpg real : 1 predict : 4
# path : 000033_male_Asian_57/mask4.jpg real : 1 predict : 4
# path : 000033_male_Asian_57/mask5.jpg real : 1 predict : 4
# path : 000034_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000034_female_Asian_55/mask1.jpg real : 4 predict : 16
# path : 000036_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000037_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000038_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000038_female_Asian_58/mask1.jpg real : 4 predict : 0
# path : 000039_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000040_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000040_female_Asian_57/mask1.jpg real : 4 predict : 0
# path : 000040_female_Asian_57/mask4.jpg real : 4 predict : 0
# path : 000041_female_Asian_58/normal.jpg real : 16 predict : 17
# path : 000041_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000041_female_Asian_58/mask1.jpg real : 4 predict : 3
# path : 000041_female_Asian_58/mask2.jpg real : 4 predict : 0
# path : 000041_female_Asian_58/mask3.jpg real : 4 predict : 0
# path : 000041_female_Asian_58/mask4.jpg real : 4 predict : 0
# path : 000043_male_Asian_56/normal.jpg real : 13 predict : 16
# path : 000043_male_Asian_56/incorrect_mask.jpg real : 7 predict : 1
# path : 000043_male_Asian_56/mask1.jpg real : 1 predict : 0
# path : 000043_male_Asian_56/mask2.jpg real : 1 predict : 0
# path : 000043_male_Asian_56/mask4.jpg real : 1 predict : 0
# path : 000043_male_Asian_56/mask5.jpg real : 1 predict : 0
# path : 000044_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000045_female_Asian_56/normal.jpg real : 16 predict : 12
# path : 000045_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000045_female_Asian_56/mask1.jpg real : 4 predict : 3
# path : 000045_female_Asian_56/mask2.jpg real : 4 predict : 0
# path : 000045_female_Asian_56/mask4.jpg real : 4 predict : 0
# path : 000046_male_Asian_55/normal.jpg real : 13 predict : 1
# path : 000046_male_Asian_55/incorrect_mask.jpg real : 7 predict : 1
# path : 000046_male_Asian_55/mask1.jpg real : 1 predict : 0
# path : 000047_male_Asian_58/normal.jpg real : 13 predict : 12
# path : 000047_male_Asian_58/incorrect_mask.jpg real : 7 predict : 1
# path : 000047_male_Asian_58/mask1.jpg real : 1 predict : 3
# path : 000047_male_Asian_58/mask4.jpg real : 1 predict : 0
# path : 000048_female_Asian_57/normal.jpg real : 16 predict : 12
# path : 000048_female_Asian_57/incorrect_mask.jpg real : 10 predict : 6
# path : 000048_female_Asian_57/mask1.jpg real : 4 predict : 0
# path : 000048_female_Asian_57/mask2.jpg real : 4 predict : 9
# path : 000048_female_Asian_57/mask3.jpg real : 4 predict : 3
# path : 000048_female_Asian_57/mask4.jpg real : 4 predict : 3
# path : 000062_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000064_male_Asian_59/normal.jpg real : 13 predict : 4
# path : 000064_male_Asian_59/incorrect_mask.jpg real : 7 predict : 4
# path : 000064_male_Asian_59/mask1.jpg real : 1 predict : 3
# path : 000064_male_Asian_59/mask2.jpg real : 1 predict : 4
# path : 000064_male_Asian_59/mask3.jpg real : 1 predict : 4
# path : 000064_male_Asian_59/mask4.jpg real : 1 predict : 4
# path : 000064_male_Asian_59/mask5.jpg real : 1 predict : 4
# path : 000066_female_Asian_53/normal.jpg real : 16 predict : 4
# path : 000066_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000067_female_Asian_54/normal.jpg real : 16 predict : 17
# path : 000067_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000067_female_Asian_54/mask1.jpg real : 4 predict : 3
# path : 000069_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000069_female_Asian_54/mask1.jpg real : 4 predict : 3
# path : 000070_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000071_female_Asian_56/normal.jpg real : 16 predict : 4
# path : 000071_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000071_female_Asian_56/mask1.jpg real : 4 predict : 3
# path : 000073_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000075_female_Asian_56/normal.jpg real : 16 predict : 15
# path : 000075_female_Asian_56/incorrect_mask.jpg real : 10 predict : 0
# path : 000075_female_Asian_56/mask1.jpg real : 4 predict : 0
# path : 000075_female_Asian_56/mask2.jpg real : 4 predict : 0
# path : 000075_female_Asian_56/mask3.jpg real : 4 predict : 0
# path : 000075_female_Asian_56/mask4.jpg real : 4 predict : 0
# path : 000077_male_Asian_59/incorrect_mask.jpg real : 7 predict : 4
# path : 000077_male_Asian_59/mask2.jpg real : 1 predict : 4
# path : 000077_male_Asian_59/mask3.jpg real : 1 predict : 4
# path : 000077_male_Asian_59/mask4.jpg real : 1 predict : 4
# path : 000077_male_Asian_59/mask5.jpg real : 1 predict : 4
# path : 000079_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000080_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000206_female_Asian_57/normal.jpg real : 16 predict : 4
# path : 000206_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000207_female_Asian_56/normal.jpg real : 16 predict : 4
# path : 000207_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000209_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000210_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000212_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000214_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000215_female_Asian_59/incorrect_mask.jpg real : 10 predict : 16
# path : 000216_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000217_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000218_female_Asian_59/normal.jpg real : 16 predict : 14
# path : 000218_female_Asian_59/incorrect_mask.jpg real : 10 predict : 16
# path : 000218_female_Asian_59/mask3.jpg real : 4 predict : 17
# path : 000219_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000221_female_Asian_40/incorrect_mask.jpg real : 10 predict : 4
# path : 000221_female_Asian_40/mask3.jpg real : 4 predict : 8
# path : 000224_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000225_female_Asian_25/normal.jpg real : 15 predict : 12
# path : 000225_female_Asian_25/incorrect_mask.jpg real : 9 predict : 3
# path : 000225_female_Asian_25/mask2.jpg real : 3 predict : 0
# path : 000225_female_Asian_25/mask3.jpg real : 3 predict : 0
# path : 000225_female_Asian_25/mask4.jpg real : 3 predict : 0
# path : 000225_female_Asian_25/mask5.jpg real : 3 predict : 0
# path : 000226_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000227_female_Asian_59/incorrect_mask.jpg real : 10 predict : 3
# path : 000227_female_Asian_59/mask3.jpg real : 4 predict : 3
# path : 000228_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000228_female_Asian_56/mask3.jpg real : 4 predict : 17
# path : 000228_female_Asian_56/mask5.jpg real : 4 predict : 11
# path : 000229_male_Asian_56/incorrect_mask.jpg real : 7 predict : 1
# path : 000229_male_Asian_56/mask5.jpg real : 1 predict : 4
# path : 000231_male_Asian_56/normal.jpg real : 13 predict : 4
# path : 000231_male_Asian_56/incorrect_mask.jpg real : 7 predict : 1
# path : 000232_male_Asian_53/normal.jpg real : 13 predict : 16
# path : 000232_male_Asian_53/incorrect_mask.jpg real : 7 predict : 1
# path : 000232_male_Asian_53/mask4.jpg real : 1 predict : 4
# path : 000235_male_Asian_57/incorrect_mask.jpg real : 7 predict : 1
# path : 000236_male_Asian_51/incorrect_mask.jpg real : 7 predict : 1
# path : 000237_male_Asian_56/incorrect_mask.jpg real : 7 predict : 1
# path : 000238_male_Asian_57/incorrect_mask.jpg real : 7 predict : 1
# path : 000238_male_Asian_57/mask4.jpg real : 1 predict : 4
# path : 000240_male_Asian_57/incorrect_mask.jpg real : 7 predict : 1
# path : 000241_male_Asian_56/normal.jpg real : 13 predict : 16
# path : 000241_male_Asian_56/incorrect_mask.jpg real : 7 predict : 1
# path : 000241_male_Asian_56/mask2.jpg real : 1 predict : 4
# path : 000241_male_Asian_56/mask5.jpg real : 1 predict : 4
# path : 000242_male_Asian_56/normal.jpg real : 13 predict : 16
# path : 000242_male_Asian_56/incorrect_mask.jpg real : 7 predict : 1
# path : 000243_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000244_female_Asian_56/normal.jpg real : 16 predict : 4
# path : 000244_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000245_male_Asian_58/normal.jpg real : 13 predict : 16
# path : 000245_male_Asian_58/incorrect_mask.jpg real : 7 predict : 1
# path : 000245_male_Asian_58/mask1.jpg real : 1 predict : 4
# path : 000245_male_Asian_58/mask4.jpg real : 1 predict : 4
# path : 000245_male_Asian_58/mask5.jpg real : 1 predict : 4
# path : 000248_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000249_male_Asian_53/incorrect_mask.jpg real : 7 predict : 0
# path : 000249_male_Asian_53/mask1.jpg real : 1 predict : 0
# path : 000255_female_Asian_59/normal.jpg real : 16 predict : 4
# path : 000255_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000256_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000256_female_Asian_58/mask1.jpg real : 4 predict : 3
# path : 000260_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000260_female_Asian_58/mask3.jpg real : 4 predict : 3
# path : 000261_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000262_male_Asian_56/incorrect_mask.jpg real : 7 predict : 4
# path : 000262_male_Asian_56/mask4.jpg real : 1 predict : 4
# path : 000263_female_Asian_48/incorrect_mask.jpg real : 10 predict : 4
# path : 000264_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000265_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000266_female_Asian_58/normal.jpg real : 16 predict : 12
# path : 000266_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000266_female_Asian_58/mask4.jpg real : 4 predict : 17
# path : 000267_male_Asian_58/incorrect_mask.jpg real : 7 predict : 1
# path : 000268_male_Asian_59/normal.jpg real : 13 predict : 1
# path : 000268_male_Asian_59/incorrect_mask.jpg real : 7 predict : 4
# path : 000268_male_Asian_59/mask2.jpg real : 1 predict : 4
# path : 000269_male_Asian_56/incorrect_mask.jpg real : 7 predict : 1
# path : 000270_female_Asian_49/normal.jpg real : 16 predict : 4
# path : 000270_female_Asian_49/incorrect_mask.jpg real : 10 predict : 4
# path : 000272_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000273_female_Asian_56/incorrect_mask.jpg real : 10 predict : 16
# path : 000273_female_Asian_56/mask4.jpg real : 4 predict : 1
# path : 000273_female_Asian_56/mask5.jpg real : 4 predict : 14
# path : 000274_female_Asian_54/incorrect_mask.jpg real : 10 predict : 3
# path : 000274_female_Asian_54/mask3.jpg real : 4 predict : 3
# path : 000274_female_Asian_54/mask5.jpg real : 4 predict : 3
# path : 000275_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000275_female_Asian_54/mask1.jpg real : 4 predict : 3
# path : 000277_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000277_female_Asian_54/mask2.jpg real : 4 predict : 3
# path : 000277_female_Asian_54/mask3.jpg real : 4 predict : 3
# path : 000277_female_Asian_54/mask4.jpg real : 4 predict : 3
# path : 000278_female_Asian_54/normal.jpg real : 16 predict : 4
# path : 000278_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000279_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000280_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000280_female_Asian_54/mask1.jpg real : 4 predict : 11
# path : 000282_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000283_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000285_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000285_female_Asian_54/mask1.jpg real : 4 predict : 3
# path : 000285_female_Asian_54/mask2.jpg real : 4 predict : 17
# path : 000285_female_Asian_54/mask4.jpg real : 4 predict : 0
# path : 000286_female_Asian_51/normal.jpg real : 16 predict : 4
# path : 000286_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000288_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000292_female_Asian_57/incorrect_mask.jpg real : 10 predict : 1
# path : 000293_female_Asian_57/normal.jpg real : 16 predict : 4
# path : 000293_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000294_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000294_female_Asian_53/mask1.jpg real : 4 predict : 1
# path : 000294_female_Asian_53/mask3.jpg real : 4 predict : 1
# path : 000296_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000296_female_Asian_57/mask3.jpg real : 4 predict : 3
# path : 000296_female_Asian_57/mask4.jpg real : 4 predict : 3
# path : 000297_female_Asian_53/incorrect_mask.jpg real : 10 predict : 9
# path : 000297_female_Asian_53/mask1.jpg real : 4 predict : 3
# path : 000297_female_Asian_53/mask3.jpg real : 4 predict : 3
# path : 000297_female_Asian_53/mask4.jpg real : 4 predict : 12
# path : 000299_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000299_female_Asian_57/mask3.jpg real : 4 predict : 1
# path : 000301_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000301_female_Asian_55/mask1.jpg real : 4 predict : 3
# path : 000302_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000302_female_Asian_56/mask1.jpg real : 4 predict : 3
# path : 000304_female_Asian_51/incorrect_mask.jpg real : 10 predict : 3
# path : 000304_female_Asian_51/mask3.jpg real : 4 predict : 17
# path : 000304_female_Asian_51/mask5.jpg real : 4 predict : 15
# path : 000309_male_Asian_29/mask1.jpg real : 0 predict : 3
# path : 000309_male_Asian_29/mask5.jpg real : 0 predict : 4
# path : 000311_female_Asian_58/incorrect_mask.jpg real : 10 predict : 3
# path : 000311_female_Asian_58/mask1.jpg real : 4 predict : 3
# path : 000312_female_Asian_57/incorrect_mask.jpg real : 10 predict : 17
# path : 000313_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000313_female_Asian_54/mask1.jpg real : 4 predict : 3
# path : 000313_female_Asian_54/mask3.jpg real : 4 predict : 17
# path : 000313_female_Asian_54/mask4.jpg real : 4 predict : 16
# path : 000336_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000336_female_Asian_56/mask1.jpg real : 4 predict : 3
# path : 000344_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000344_female_Asian_57/mask4.jpg real : 4 predict : 3
# path : 000344_female_Asian_57/mask5.jpg real : 4 predict : 16
# path : 000348_male_Asian_58/normal.jpg real : 13 predict : 16
# path : 000348_male_Asian_58/incorrect_mask.jpg real : 7 predict : 1
# path : 000348_male_Asian_58/mask5.jpg real : 1 predict : 4
# path : 000356_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000357_female_Asian_55/incorrect_mask.jpg real : 10 predict : 16
# path : 000376_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000378_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000381_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000498_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000499_female_Asian_58/incorrect_mask.jpg real : 10 predict : 1
# path : 000511_female_Asian_55/incorrect_mask.jpg real : 10 predict : 0
# path : 000511_female_Asian_55/mask1.jpg real : 4 predict : 0
# path : 000511_female_Asian_55/mask3.jpg real : 4 predict : 0
# path : 000511_female_Asian_55/mask4.jpg real : 4 predict : 0
# path : 000512_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000513_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000514_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000515_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000516_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000517_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000517_female_Asian_58/mask1.jpg real : 4 predict : 16
# path : 000517_female_Asian_58/mask5.jpg real : 4 predict : 1
# path : 000518_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000519_female_Asian_56/incorrect_mask.jpg real : 10 predict : 16
# path : 000520_female_Asian_59/incorrect_mask.jpg real : 10 predict : 3
# path : 000522_female_Asian_51/normal.jpg real : 16 predict : 12
# path : 000522_female_Asian_51/incorrect_mask.jpg real : 10 predict : 3
# path : 000522_female_Asian_51/mask1.jpg real : 4 predict : 3
# path : 000522_female_Asian_51/mask3.jpg real : 4 predict : 0
# path : 000522_female_Asian_51/mask4.jpg real : 4 predict : 3
# path : 000522_female_Asian_51/mask5.jpg real : 4 predict : 3
# path : 000523_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000523_female_Asian_51/mask1.jpg real : 4 predict : 0
# path : 000525_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000526_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000527_female_Asian_58/normal.jpg real : 16 predict : 4
# path : 000527_female_Asian_58/incorrect_mask.jpg real : 10 predict : 3
# path : 000527_female_Asian_58/mask2.jpg real : 4 predict : 3
# path : 000527_female_Asian_58/mask4.jpg real : 4 predict : 16
# path : 000527_female_Asian_58/mask5.jpg real : 4 predict : 17
# path : 000528_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000528_female_Asian_51/mask1.jpg real : 4 predict : 0
# path : 000528_female_Asian_51/mask3.jpg real : 4 predict : 0
# path : 000529_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000531_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000531_female_Asian_56/mask1.jpg real : 4 predict : 0
# path : 000531_female_Asian_56/mask5.jpg real : 4 predict : 0
# path : 000532_female_Asian_57/normal.jpg real : 16 predict : 4
# path : 000532_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000533_female_Asian_54/incorrect_mask.jpg real : 10 predict : 3
# path : 000533_female_Asian_54/mask3.jpg real : 4 predict : 3
# path : 000534_female_Asian_50/incorrect_mask.jpg real : 10 predict : 0
# path : 000534_female_Asian_50/mask1.jpg real : 4 predict : 3
# path : 000535_female_Asian_50/incorrect_mask.jpg real : 10 predict : 0
# path : 000535_female_Asian_50/mask1.jpg real : 4 predict : 0
# path : 000536_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000536_female_Asian_51/mask3.jpg real : 4 predict : 3
# path : 000538_male_Asian_54/normal.jpg real : 13 predict : 16
# path : 000538_male_Asian_54/incorrect_mask.jpg real : 7 predict : 1
# path : 000538_male_Asian_54/mask2.jpg real : 1 predict : 4
# path : 000538_male_Asian_54/mask4.jpg real : 1 predict : 4
# path : 000538_male_Asian_54/mask5.jpg real : 1 predict : 4
# path : 000539_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000541_female_Asian_35/incorrect_mask.jpg real : 10 predict : 3
# path : 000541_female_Asian_35/mask1.jpg real : 4 predict : 17
# path : 000541_female_Asian_35/mask4.jpg real : 4 predict : 3
# path : 000541_female_Asian_35/mask5.jpg real : 4 predict : 14
# path : 000542_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000543_male_Asian_35/normal.jpg real : 13 predict : 12
# path : 000543_male_Asian_35/incorrect_mask.jpg real : 7 predict : 16
# path : 000543_male_Asian_35/mask1.jpg real : 1 predict : 0
# path : 000543_male_Asian_35/mask2.jpg real : 1 predict : 3
# path : 000543_male_Asian_35/mask3.jpg real : 1 predict : 0
# path : 000543_male_Asian_35/mask4.jpg real : 1 predict : 0
# path : 000543_male_Asian_35/mask5.jpg real : 1 predict : 0
# path : 000545_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000546_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000546_female_Asian_52/mask2.jpg real : 4 predict : 16
# path : 000547_female_Asian_55/incorrect_mask.jpg real : 10 predict : 3
# path : 000547_female_Asian_55/mask1.jpg real : 4 predict : 3
# path : 000547_female_Asian_55/mask3.jpg real : 4 predict : 13
# path : 000548_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000549_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000549_female_Asian_58/mask1.jpg real : 4 predict : 3
# path : 000550_male_Asian_56/incorrect_mask.jpg real : 7 predict : 1
# path : 000552_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000553_female_Asian_58/incorrect_mask.jpg real : 10 predict : 16
# path : 000554_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000554_female_Asian_54/mask1.jpg real : 4 predict : 1
# path : 000556_male_Asian_57/incorrect_mask.jpg real : 7 predict : 1
# path : 000557_female_Asian_57/incorrect_mask.jpg real : 10 predict : 12
# path : 000557_female_Asian_57/mask3.jpg real : 4 predict : 12
# path : 000558_female_Asian_58/incorrect_mask.jpg real : 10 predict : 16
# path : 000559_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000560_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000561_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000562_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000563_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000564_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000565_female_Asian_35/incorrect_mask.jpg real : 10 predict : 3
# path : 000565_female_Asian_35/mask1.jpg real : 4 predict : 3
# path : 000565_female_Asian_35/mask2.jpg real : 4 predict : 0
# path : 000565_female_Asian_35/mask4.jpg real : 4 predict : 3
# path : 000565_female_Asian_35/mask5.jpg real : 4 predict : 0
# path : 000566_male_Asian_58/normal.jpg real : 13 predict : 16
# path : 000566_male_Asian_58/incorrect_mask.jpg real : 7 predict : 4
# path : 000566_male_Asian_58/mask2.jpg real : 1 predict : 8
# path : 000567_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000568_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000570_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000571_male_Asian_51/normal.jpg real : 13 predict : 16
# path : 000571_male_Asian_51/incorrect_mask.jpg real : 7 predict : 1
# path : 000572_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000573_female_Asian_50/incorrect_mask.jpg real : 10 predict : 0
# path : 000573_female_Asian_50/mask1.jpg real : 4 predict : 0
# path : 000573_female_Asian_50/mask2.jpg real : 4 predict : 0
# path : 000573_female_Asian_50/mask4.jpg real : 4 predict : 0
# path : 000574_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000574_female_Asian_56/mask4.jpg real : 4 predict : 0
# path : 000574_female_Asian_56/mask5.jpg real : 4 predict : 0
# path : 000575_male_Asian_55/incorrect_mask.jpg real : 7 predict : 1
# path : 000576_female_Asian_56/incorrect_mask.jpg real : 10 predict : 3
# path : 000577_female_Asian_57/mask5.jpg real : 4 predict : 13
# path : 000588_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000588_female_Asian_58/mask5.jpg real : 4 predict : 17
# path : 000589_female_Asian_56/incorrect_mask.jpg real : 10 predict : 1
# path : 000589_female_Asian_56/mask1.jpg real : 4 predict : 1
# path : 000590_male_Asian_52/incorrect_mask.jpg real : 7 predict : 8
# path : 000590_male_Asian_52/mask5.jpg real : 1 predict : 4
# path : 000591_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000591_female_Asian_55/mask2.jpg real : 4 predict : 3
# path : 000592_female_Asian_57/normal.jpg real : 16 predict : 12
# path : 000592_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000593_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000593_female_Asian_58/mask1.jpg real : 4 predict : 0
# path : 000593_female_Asian_58/mask2.jpg real : 4 predict : 0
# path : 000593_female_Asian_58/mask3.jpg real : 4 predict : 0
# path : 000593_female_Asian_58/mask4.jpg real : 4 predict : 0
# path : 000594_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000594_female_Asian_57/mask3.jpg real : 4 predict : 17
# path : 000595_male_Asian_56/normal.jpg real : 13 predict : 16
# path : 000595_male_Asian_56/incorrect_mask.jpg real : 7 predict : 4
# path : 000595_male_Asian_56/mask1.jpg real : 1 predict : 4
# path : 000595_male_Asian_56/mask2.jpg real : 1 predict : 4
# path : 000595_male_Asian_56/mask3.jpg real : 1 predict : 4
# path : 000595_male_Asian_56/mask4.jpg real : 1 predict : 4
# path : 000595_male_Asian_56/mask5.jpg real : 1 predict : 4
# path : 000596_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000596_female_Asian_55/mask1.jpg real : 4 predict : 3
# path : 000597_male_Asian_57/normal.jpg real : 13 predict : 16
# path : 000597_male_Asian_57/incorrect_mask.jpg real : 7 predict : 4
# path : 000597_male_Asian_57/mask1.jpg real : 1 predict : 4
# path : 000597_male_Asian_57/mask4.jpg real : 1 predict : 0
# path : 000597_male_Asian_57/mask5.jpg real : 1 predict : 4
# path : 000598_female_Asian_54/incorrect_mask.jpg real : 10 predict : 0
# path : 000600_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000600-1_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000601_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000602_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000602_female_Asian_50/mask1.jpg real : 4 predict : 0
# path : 000605_male_Asian_57/normal.jpg real : 13 predict : 16
# path : 000605_male_Asian_57/incorrect_mask.jpg real : 7 predict : 4
# path : 000605_male_Asian_57/mask1.jpg real : 1 predict : 4
# path : 000605_male_Asian_57/mask2.jpg real : 1 predict : 4
# path : 000605_male_Asian_57/mask3.jpg real : 1 predict : 4
# path : 000605_male_Asian_57/mask4.jpg real : 1 predict : 4
# path : 000605_male_Asian_57/mask5.jpg real : 1 predict : 4
# path : 000606_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000609_male_Asian_57/normal.jpg real : 13 predict : 16
# path : 000609_male_Asian_57/incorrect_mask.jpg real : 7 predict : 1
# path : 000609_male_Asian_57/mask4.jpg real : 1 predict : 4
# path : 000609_male_Asian_57/mask5.jpg real : 1 predict : 4
# path : 000610_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000611_male_Asian_51/normal.jpg real : 13 predict : 1
# path : 000611_male_Asian_51/incorrect_mask.jpg real : 7 predict : 1
# path : 000611_male_Asian_51/mask5.jpg real : 1 predict : 4
# path : 000613_male_Asian_51/incorrect_mask.jpg real : 7 predict : 4
# path : 000613_male_Asian_51/mask2.jpg real : 1 predict : 4
# path : 000613_male_Asian_51/mask4.jpg real : 1 predict : 4
# path : 000613_male_Asian_51/mask5.jpg real : 1 predict : 4
# path : 000614_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000615_male_Asian_56/normal.jpg real : 13 predict : 16
# path : 000615_male_Asian_56/incorrect_mask.jpg real : 7 predict : 4
# path : 000615_male_Asian_56/mask1.jpg real : 1 predict : 4
# path : 000615_male_Asian_56/mask2.jpg real : 1 predict : 4
# path : 000615_male_Asian_56/mask3.jpg real : 1 predict : 4
# path : 000615_male_Asian_56/mask4.jpg real : 1 predict : 0
# path : 000615_male_Asian_56/mask5.jpg real : 1 predict : 4
# path : 000616_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000616_female_Asian_57/mask1.jpg real : 4 predict : 17
# path : 000618_male_Asian_37/normal.jpg real : 13 predict : 12
# path : 000618_male_Asian_37/incorrect_mask.jpg real : 7 predict : 1
# path : 000618_male_Asian_37/mask1.jpg real : 1 predict : 4
# path : 000618_male_Asian_37/mask2.jpg real : 1 predict : 0
# path : 000618_male_Asian_37/mask4.jpg real : 1 predict : 0
# path : 000618_male_Asian_37/mask5.jpg real : 1 predict : 12
# path : 000619_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000620_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000621_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000621_female_Asian_57/mask4.jpg real : 4 predict : 17
# path : 000622_male_Asian_56/incorrect_mask.jpg real : 7 predict : 1
# path : 000622_male_Asian_56/mask1.jpg real : 1 predict : 4
# path : 000622_male_Asian_56/mask5.jpg real : 1 predict : 4
# path : 000623_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000623_female_Asian_57/mask2.jpg real : 4 predict : 17
# path : 000625_male_Asian_57/normal.jpg real : 13 predict : 16
# path : 000625_male_Asian_57/incorrect_mask.jpg real : 7 predict : 1
# path : 000625_male_Asian_57/mask1.jpg real : 1 predict : 4
# path : 000625_male_Asian_57/mask2.jpg real : 1 predict : 4
# path : 000625_male_Asian_57/mask3.jpg real : 1 predict : 4
# path : 000625_male_Asian_57/mask4.jpg real : 1 predict : 4
# path : 000625_male_Asian_57/mask5.jpg real : 1 predict : 4
# path : 000626_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000628_male_Asian_51/normal.jpg real : 13 predict : 16
# path : 000628_male_Asian_51/incorrect_mask.jpg real : 7 predict : 4
# path : 000628_male_Asian_51/mask1.jpg real : 1 predict : 4
# path : 000628_male_Asian_51/mask2.jpg real : 1 predict : 4
# path : 000628_male_Asian_51/mask3.jpg real : 1 predict : 4
# path : 000628_male_Asian_51/mask4.jpg real : 1 predict : 4
# path : 000628_male_Asian_51/mask5.jpg real : 1 predict : 4
# path : 000629_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000630_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000631_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000632_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000633_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000635_female_Asian_58/normal.jpg real : 16 predict : 4
# path : 000635_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000636_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000637_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000637_female_Asian_50/mask1.jpg real : 4 predict : 3
# path : 000637_female_Asian_50/mask4.jpg real : 4 predict : 17
# path : 000639_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000640_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000641_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000641_female_Asian_57/mask1.jpg real : 4 predict : 0
# path : 000641_female_Asian_57/mask2.jpg real : 4 predict : 0
# path : 000642_female_Asian_54/incorrect_mask.jpg real : 10 predict : 1
# path : 000643_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000644_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000645_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000646_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000647_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000650_male_Asian_54/normal.jpg real : 13 predict : 16
# path : 000650_male_Asian_54/incorrect_mask.jpg real : 7 predict : 4
# path : 000650_male_Asian_54/mask1.jpg real : 1 predict : 4
# path : 000650_male_Asian_54/mask2.jpg real : 1 predict : 4
# path : 000650_male_Asian_54/mask3.jpg real : 1 predict : 0
# path : 000650_male_Asian_54/mask4.jpg real : 1 predict : 4
# path : 000650_male_Asian_54/mask5.jpg real : 1 predict : 3
# path : 000651_male_Asian_54/normal.jpg real : 13 predict : 16
# path : 000651_male_Asian_54/incorrect_mask.jpg real : 7 predict : 4
# path : 000651_male_Asian_54/mask1.jpg real : 1 predict : 4
# path : 000651_male_Asian_54/mask2.jpg real : 1 predict : 4
# path : 000651_male_Asian_54/mask3.jpg real : 1 predict : 4
# path : 000651_male_Asian_54/mask5.jpg real : 1 predict : 4
# path : 000652_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000653_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000654_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000655_male_Asian_53/incorrect_mask.jpg real : 7 predict : 4
# path : 000655_male_Asian_53/mask2.jpg real : 1 predict : 4
# path : 000655_male_Asian_53/mask4.jpg real : 1 predict : 4
# path : 000655_male_Asian_53/mask5.jpg real : 1 predict : 4
# path : 000656_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000657_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000658_male_Asian_58/incorrect_mask.jpg real : 7 predict : 4
# path : 000658_male_Asian_58/mask1.jpg real : 1 predict : 4
# path : 000658_male_Asian_58/mask2.jpg real : 1 predict : 0
# path : 000658_male_Asian_58/mask3.jpg real : 1 predict : 4
# path : 000658_male_Asian_58/mask4.jpg real : 1 predict : 4
# path : 000658_male_Asian_58/mask5.jpg real : 1 predict : 4
# path : 000659_male_Asian_58/incorrect_mask.jpg real : 7 predict : 1
# path : 000661_male_Asian_55/incorrect_mask.jpg real : 7 predict : 1
# path : 000661_male_Asian_55/mask5.jpg real : 1 predict : 4
# path : 000662_female_Asian_53/incorrect_mask.jpg real : 10 predict : 1
# path : 000663_female_Asian_57/incorrect_mask.jpg real : 10 predict : 16
# path : 000663_female_Asian_57/mask2.jpg real : 4 predict : 16
# path : 000664_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000665_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000665_female_Asian_54/mask2.jpg real : 4 predict : 11
# path : 000667_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000668_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000669_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000670_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000671_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000672_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000673_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000675_female_Asian_59/incorrect_mask.jpg real : 10 predict : 4
# path : 000676_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000678_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000679_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000684_female_Asian_56/normal.jpg real : 16 predict : 12
# path : 000684_female_Asian_56/incorrect_mask.jpg real : 10 predict : 1
# path : 000684_female_Asian_56/mask1.jpg real : 4 predict : 0
# path : 000685_male_Asian_19/normal.jpg real : 12 predict : 13
# path : 000685_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 000686_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000686_female_Asian_52/mask3.jpg real : 4 predict : 17
# path : 000687_male_Asian_50/normal.jpg real : 13 predict : 16
# path : 000687_male_Asian_50/incorrect_mask.jpg real : 7 predict : 1
# path : 000687_male_Asian_50/mask1.jpg real : 1 predict : 4
# path : 000687_male_Asian_50/mask2.jpg real : 1 predict : 4
# path : 000687_male_Asian_50/mask3.jpg real : 1 predict : 4
# path : 000687_male_Asian_50/mask4.jpg real : 1 predict : 4
# path : 000687_male_Asian_50/mask5.jpg real : 1 predict : 4
# path : 000688_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000689_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000690_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000691_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000692_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000693_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000693_female_Asian_54/mask3.jpg real : 4 predict : 16
# path : 000694_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000695_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000696_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000697_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000697_female_Asian_58/mask3.jpg real : 4 predict : 1
# path : 000697_female_Asian_58/mask4.jpg real : 4 predict : 1
# path : 000698_female_Asian_55/incorrect_mask.jpg real : 10 predict : 8
# path : 000699_female_Asian_57/incorrect_mask.jpg real : 10 predict : 1
# path : 000700_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000711_female_Asian_53/incorrect_mask.jpg real : 10 predict : 16
# path : 000712_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000712_female_Asian_50/mask5.jpg real : 4 predict : 16
# path : 000713_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000714_female_Asian_51/incorrect_mask.jpg real : 10 predict : 16
# path : 000715_female_Asian_56/incorrect_mask.jpg real : 10 predict : 1
# path : 000715_female_Asian_56/mask1.jpg real : 4 predict : 3
# path : 000715_female_Asian_56/mask3.jpg real : 4 predict : 14
# path : 000716_male_Asian_51/normal.jpg real : 13 predict : 16
# path : 000716_male_Asian_51/incorrect_mask.jpg real : 7 predict : 1
# path : 000717_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000718_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000719_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000720_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000721_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000721_female_Asian_53/mask3.jpg real : 4 predict : 17
# path : 000722_female_Asian_56/normal.jpg real : 16 predict : 4
# path : 000722_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000723_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000724_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000724_female_Asian_57/mask3.jpg real : 4 predict : 14
# path : 000725_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000726_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000728_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000729_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000730_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000731_male_Asian_58/normal.jpg real : 13 predict : 16
# path : 000731_male_Asian_58/incorrect_mask.jpg real : 7 predict : 4
# path : 000731_male_Asian_58/mask1.jpg real : 1 predict : 4
# path : 000731_male_Asian_58/mask2.jpg real : 1 predict : 4
# path : 000731_male_Asian_58/mask3.jpg real : 1 predict : 4
# path : 000731_male_Asian_58/mask4.jpg real : 1 predict : 4
# path : 000731_male_Asian_58/mask5.jpg real : 1 predict : 4
# path : 000732_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000733_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000735_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000736_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000736_female_Asian_53/mask1.jpg real : 4 predict : 1
# path : 000736_female_Asian_53/mask3.jpg real : 4 predict : 8
# path : 000737_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000738_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000739_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000740_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000741_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000742_female_Asian_58/incorrect_mask.jpg real : 10 predict : 3
# path : 000742_female_Asian_58/mask1.jpg real : 4 predict : 3
# path : 000742_female_Asian_58/mask2.jpg real : 4 predict : 15
# path : 000742_female_Asian_58/mask3.jpg real : 4 predict : 3
# path : 000743_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000745_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000746_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000747_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000748_female_Asian_55/incorrect_mask.jpg real : 10 predict : 16
# path : 000748_female_Asian_55/mask2.jpg real : 4 predict : 3
# path : 000748_female_Asian_55/mask3.jpg real : 4 predict : 3
# path : 000748-1_female_Asian_54/incorrect_mask.jpg real : 10 predict : 1
# path : 000750_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000751_female_Asian_56/normal.jpg real : 16 predict : 13
# path : 000751_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000751_female_Asian_56/mask2.jpg real : 4 predict : 16
# path : 000754_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000755_female_Asian_53/incorrect_mask.jpg real : 10 predict : 4
# path : 000758_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000759_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000760_female_Asian_50/incorrect_mask.jpg real : 10 predict : 12
# path : 000760_female_Asian_50/mask1.jpg real : 4 predict : 3
# path : 000760_female_Asian_50/mask2.jpg real : 4 predict : 0
# path : 000760_female_Asian_50/mask3.jpg real : 4 predict : 0
# path : 000760_female_Asian_50/mask4.jpg real : 4 predict : 0
# path : 000760_female_Asian_50/mask5.jpg real : 4 predict : 0
# path : 000763_female_Asian_55/incorrect_mask.jpg real : 10 predict : 4
# path : 000764_female_Asian_56/normal.jpg real : 16 predict : 4
# path : 000764_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000765_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000766_female_Asian_53/incorrect_mask.jpg real : 10 predict : 16
# path : 000766_female_Asian_53/mask1.jpg real : 4 predict : 3
# path : 000767_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000767_female_Asian_56/mask2.jpg real : 4 predict : 1
# path : 000768_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000769_female_Asian_56/incorrect_mask.jpg real : 10 predict : 16
# path : 000770_female_Asian_50/normal.jpg real : 16 predict : 12
# path : 000770_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000770_female_Asian_50/mask2.jpg real : 4 predict : 0
# path : 000770_female_Asian_50/mask3.jpg real : 4 predict : 14
# path : 000771_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000772_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000773_female_Asian_57/incorrect_mask.jpg real : 10 predict : 1
# path : 000775_male_Asian_56/normal.jpg real : 13 predict : 16
# path : 000775_male_Asian_56/incorrect_mask.jpg real : 7 predict : 4
# path : 000775_male_Asian_56/mask1.jpg real : 1 predict : 0
# path : 000775_male_Asian_56/mask3.jpg real : 1 predict : 0
# path : 000776_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# path : 000778_female_Asian_56/incorrect_mask.jpg real : 10 predict : 4
# path : 000779_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000781_male_Asian_51/normal.jpg real : 13 predict : 16
# path : 000781_male_Asian_51/incorrect_mask.jpg real : 7 predict : 4
# path : 000781_male_Asian_51/mask1.jpg real : 1 predict : 4
# path : 000781_male_Asian_51/mask3.jpg real : 1 predict : 4
# path : 000781_male_Asian_51/mask4.jpg real : 1 predict : 4
# path : 000781_male_Asian_51/mask5.jpg real : 1 predict : 4
# path : 000782_female_Asian_58/incorrect_mask.jpg real : 10 predict : 4
# path : 000783_male_Asian_58/normal.jpg real : 13 predict : 1
# path : 000783_male_Asian_58/incorrect_mask.jpg real : 7 predict : 1
# path : 000786_female_Asian_50/incorrect_mask.jpg real : 10 predict : 4
# path : 000789_female_Asian_54/incorrect_mask.jpg real : 10 predict : 4
# path : 000797_female_Asian_56/incorrect_mask.jpg real : 10 predict : 16
# path : 000797_female_Asian_56/mask4.jpg real : 4 predict : 14
# path : 000799_female_Asian_51/incorrect_mask.jpg real : 10 predict : 16
# path : 000799_female_Asian_51/mask1.jpg real : 4 predict : 0
# path : 000799_female_Asian_51/mask3.jpg real : 4 predict : 12
# path : 000801_male_Asian_59/normal.jpg real : 13 predict : 16
# path : 000801_male_Asian_59/incorrect_mask.jpg real : 7 predict : 4
# path : 000801_male_Asian_59/mask1.jpg real : 1 predict : 4
# path : 000801_male_Asian_59/mask2.jpg real : 1 predict : 4
# path : 000801_male_Asian_59/mask4.jpg real : 1 predict : 4
# path : 000801_male_Asian_59/mask5.jpg real : 1 predict : 4
# path : 000802_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000807_male_Asian_59/incorrect_mask.jpg real : 7 predict : 1
# path : 000808_male_Asian_54/incorrect_mask.jpg real : 7 predict : 1
# path : 000808_male_Asian_54/mask5.jpg real : 1 predict : 4
# path : 000809_male_Asian_51/normal.jpg real : 13 predict : 16
# path : 000809_male_Asian_51/incorrect_mask.jpg real : 7 predict : 4
# path : 000809_male_Asian_51/mask2.jpg real : 1 predict : 0
# path : 000809_male_Asian_51/mask4.jpg real : 1 predict : 0
# path : 000809_male_Asian_51/mask5.jpg real : 1 predict : 4
# path : 000810_male_Asian_58/normal.jpg real : 13 predict : 16
# path : 000810_male_Asian_58/incorrect_mask.jpg real : 7 predict : 1
# path : 000811_male_Asian_55/normal.jpg real : 13 predict : 16
# path : 000811_male_Asian_55/incorrect_mask.jpg real : 7 predict : 1
# path : 000811_male_Asian_55/mask5.jpg real : 1 predict : 4
# path : 000812_male_Asian_55/normal.jpg real : 13 predict : 16
# path : 000812_male_Asian_55/incorrect_mask.jpg real : 7 predict : 1
# path : 000814_male_Asian_56/incorrect_mask.jpg real : 7 predict : 16
# path : 000815_female_Asian_51/incorrect_mask.jpg real : 10 predict : 4
# path : 000816_female_Asian_54/incorrect_mask.jpg real : 10 predict : 16
# path : 000817_female_Asian_52/incorrect_mask.jpg real : 10 predict : 4
# path : 000818_female_Asian_52/incorrect_mask.jpg real : 10 predict : 1
# path : 000819_female_Asian_57/normal.jpg real : 16 predict : 4
# path : 000819_female_Asian_57/incorrect_mask.jpg real : 10 predict : 4
# ...
# path : 006571_female_Asian_21/normal.jpg real : 15 predict : 3
# path : 006571_female_Asian_21/incorrect_mask.jpg real : 9 predict : 3
# path : 006578_male_Asian_19/normal.jpg real : 12 predict : 14
# path : 006578_male_Asian_19/incorrect_mask.jpg real : 6 predict : 3
# path : 006578_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006578_male_Asian_19/mask2.jpg real : 0 predict : 3
# path : 006578_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006578_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006578_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006579_female_Asian_20/incorrect_mask.jpg real : 9 predict : 3
# path : 006579_female_Asian_20/mask2.jpg real : 3 predict : 4
# path : 006579_female_Asian_20/mask5.jpg real : 3 predict : 4
# path : 006580_female_Asian_20/incorrect_mask.jpg real : 9 predict : 3
# path : 006582_female_Asian_20/incorrect_mask.jpg real : 9 predict : 3
# path : 006584_female_Asian_20/incorrect_mask.jpg real : 9 predict : 3
# path : 006589_female_Asian_20/normal.jpg real : 15 predict : 14
# path : 006589_female_Asian_20/incorrect_mask.jpg real : 9 predict : 3
# path : 006593_female_Asian_20/incorrect_mask.jpg real : 9 predict : 3
# path : 006596_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006603_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006603_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006603_male_Asian_19/mask2.jpg real : 0 predict : 3
# path : 006603_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006603_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006603_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006605_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006606_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006607_male_Asian_19/incorrect_mask.jpg real : 6 predict : 1
# path : 006607_male_Asian_19/mask5.jpg real : 0 predict : 1
# path : 006608_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006608_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006608_male_Asian_19/mask5.jpg real : 0 predict : 12
# path : 006612_male_Asian_19/mask5.jpg real : 0 predict : 12
# path : 006613_male_Asian_19/incorrect_mask.jpg real : 6 predict : 4
# path : 006614_male_Asian_19/mask5.jpg real : 0 predict : 12
# path : 006615_male_Asian_19/normal.jpg real : 12 predict : 3
# path : 006615_male_Asian_19/incorrect_mask.jpg real : 6 predict : 14
# path : 006615_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006615_male_Asian_19/mask2.jpg real : 0 predict : 3
# path : 006615_male_Asian_19/mask3.jpg real : 0 predict : 4
# path : 006615_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006615_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006616_male_Asian_20/incorrect_mask.jpg real : 6 predict : 12
# path : 006616_male_Asian_20/mask1.jpg real : 0 predict : 3
# path : 006616_male_Asian_20/mask5.jpg real : 0 predict : 12
# path : 006617_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006618_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006622_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006623_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006623_male_Asian_19/mask5.jpg real : 0 predict : 12
# path : 006626_male_Asian_19/incorrect_mask.jpg real : 6 predict : 12
# path : 006626_male_Asian_19/mask5.jpg real : 0 predict : 12
# path : 006628_female_Asian_19/incorrect_mask.jpg real : 9 predict : 3
# path : 006629_female_Asian_19/normal.jpg real : 15 predict : 3
# path : 006629_female_Asian_19/incorrect_mask.jpg real : 9 predict : 3
# path : 006631_female_Asian_19/normal.jpg real : 15 predict : 12
# path : 006631_female_Asian_19/incorrect_mask.jpg real : 9 predict : 3
# path : 006635_female_Asian_19/incorrect_mask.jpg real : 9 predict : 0
# path : 006635_female_Asian_19/mask1.jpg real : 3 predict : 0
# path : 006635_female_Asian_19/mask3.jpg real : 3 predict : 0
# path : 006635_female_Asian_19/mask4.jpg real : 3 predict : 0
# path : 006636_female_Asian_19/normal.jpg real : 15 predict : 12
# path : 006636_female_Asian_19/incorrect_mask.jpg real : 9 predict : 3
# path : 006636_female_Asian_19/mask4.jpg real : 3 predict : 4
# path : 006636_female_Asian_19/mask5.jpg real : 3 predict : 4
# path : 006637_female_Asian_19/mask2.jpg real : 3 predict : 0
# path : 006639_male_Asian_19/incorrect_mask.jpg real : 6 predict : 3
# path : 006643_male_Asian_19/incorrect_mask.jpg real : 6 predict : 4
# path : 006644_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006648_female_Asian_19/normal.jpg real : 15 predict : 3
# path : 006648_female_Asian_19/incorrect_mask.jpg real : 9 predict : 3
# path : 006649_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006649_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006649_male_Asian_19/mask2.jpg real : 0 predict : 3
# path : 006649_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006649_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006651_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006652_male_Asian_20/incorrect_mask.jpg real : 6 predict : 0
# path : 006653_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006654_male_Asian_19/normal.jpg real : 12 predict : 15
# path : 006654_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006654_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006654_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006655_male_Asian_20/incorrect_mask.jpg real : 6 predict : 0
# path : 006656_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006657_male_Asian_20/incorrect_mask.jpg real : 6 predict : 3
# path : 006657_male_Asian_20/mask1.jpg real : 0 predict : 3
# path : 006657_male_Asian_20/mask5.jpg real : 0 predict : 12
# path : 006658_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006658_male_Asian_19/mask3.jpg real : 0 predict : 14
# path : 006658_male_Asian_19/mask5.jpg real : 0 predict : 14
# path : 006659_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006660_male_Asian_19/mask5.jpg real : 0 predict : 12
# path : 006661_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006661_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006664_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006664_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006665_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006666_male_Asian_20/incorrect_mask.jpg real : 6 predict : 0
# path : 006667_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006669_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006669_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006669_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006670_male_Asian_19/incorrect_mask.jpg real : 6 predict : 12
# path : 006671_male_Asian_19/mask2.jpg real : 0 predict : 1
# path : 006671_male_Asian_19/mask5.jpg real : 0 predict : 12
# path : 006672_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006673_male_Asian_19/normal.jpg real : 12 predict : 16
# path : 006673_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006673_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006674_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006675_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006676_male_Asian_20/incorrect_mask.jpg real : 6 predict : 0
# path : 006677_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006678_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006680_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006680_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006680_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006680_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006682_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006684_male_Asian_19/incorrect_mask.jpg real : 6 predict : 3
# path : 006687_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006688_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006691_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006694_female_Asian_19/incorrect_mask.jpg real : 9 predict : 3
# path : 006699_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006706_male_Asian_20/mask3.jpg real : 0 predict : 3
# path : 006706_male_Asian_20/mask4.jpg real : 0 predict : 3
# path : 006707_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006708_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006709_male_Asian_19/incorrect_mask.jpg real : 6 predict : 3
# path : 006709_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006710_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006711_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006712_male_Asian_20/mask1.jpg real : 0 predict : 3
# path : 006714_male_Asian_20/incorrect_mask.jpg real : 6 predict : 0
# path : 006715_male_Asian_21/incorrect_mask.jpg real : 6 predict : 0
# path : 006716_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006717_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006718_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006719_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006722_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006724_male_Asian_19/incorrect_mask.jpg real : 6 predict : 1
# path : 006725_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006726_male_Asian_19/normal.jpg real : 12 predict : 15
# path : 006726_male_Asian_19/incorrect_mask.jpg real : 6 predict : 9
# path : 006726_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006726_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006726_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006726_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006727_male_Asian_20/incorrect_mask.jpg real : 6 predict : 0
# path : 006728_male_Asian_19/incorrect_mask.jpg real : 6 predict : 3
# path : 006729_male_Asian_19/incorrect_mask.jpg real : 6 predict : 1
# path : 006731_male_Asian_19/incorrect_mask.jpg real : 6 predict : 4
# path : 006731_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006731_male_Asian_19/mask2.jpg real : 0 predict : 3
# path : 006731_male_Asian_19/mask5.jpg real : 0 predict : 4
# path : 006732_male_Asian_19/normal.jpg real : 12 predict : 3
# path : 006732_male_Asian_19/incorrect_mask.jpg real : 6 predict : 3
# path : 006732_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006732_male_Asian_19/mask2.jpg real : 0 predict : 4
# path : 006732_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006732_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006732_male_Asian_19/mask5.jpg real : 0 predict : 4
# path : 006737_female_Asian_19/incorrect_mask.jpg real : 9 predict : 3
# path : 006737_female_Asian_19/mask5.jpg real : 3 predict : 15
# path : 006738_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006742_male_Asian_19/normal.jpg real : 12 predict : 13
# path : 006742_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006743_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006743_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006744_male_Asian_20/incorrect_mask.jpg real : 6 predict : 0
# path : 006745_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006746_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006748_male_Asian_19/normal.jpg real : 12 predict : 15
# path : 006748_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006748_male_Asian_19/mask1.jpg real : 0 predict : 17
# path : 006748_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006749_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006749_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006749_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006750_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006752_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006752_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006752_male_Asian_19/mask3.jpg real : 0 predict : 12
# path : 006753_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006754_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006755_male_Asian_19/normal.jpg real : 12 predict : 15
# path : 006755_male_Asian_19/incorrect_mask.jpg real : 6 predict : 9
# path : 006755_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006755_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006755_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006755_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006900_female_Asian_19/incorrect_mask.jpg real : 9 predict : 3
# path : 006905_male_Asian_19/normal.jpg real : 12 predict : 4
# path : 006905_male_Asian_19/incorrect_mask.jpg real : 6 predict : 4
# path : 006905_male_Asian_19/mask1.jpg real : 0 predict : 4
# path : 006905_male_Asian_19/mask2.jpg real : 0 predict : 4
# path : 006905_male_Asian_19/mask3.jpg real : 0 predict : 4
# path : 006921_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006924_male_Asian_19/normal.jpg real : 12 predict : 0
# path : 006924_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006926_male_Asian_19/normal.jpg real : 12 predict : 1
# path : 006926_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006926_male_Asian_19/mask2.jpg real : 0 predict : 4
# path : 006926_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006926_male_Asian_19/mask5.jpg real : 0 predict : 4
# path : 006927_male_Asian_19/normal.jpg real : 12 predict : 4
# path : 006927_male_Asian_19/incorrect_mask.jpg real : 6 predict : 4
# path : 006927_male_Asian_19/mask3.jpg real : 0 predict : 4
# path : 006927_male_Asian_19/mask4.jpg real : 0 predict : 4
# path : 006927_male_Asian_19/mask5.jpg real : 0 predict : 4
# path : 006928_male_Asian_19/normal.jpg real : 12 predict : 16
# path : 006928_male_Asian_19/incorrect_mask.jpg real : 6 predict : 4
# path : 006928_male_Asian_19/mask1.jpg real : 0 predict : 4
# path : 006928_male_Asian_19/mask2.jpg real : 0 predict : 4
# path : 006928_male_Asian_19/mask3.jpg real : 0 predict : 4
# path : 006928_male_Asian_19/mask4.jpg real : 0 predict : 4
# path : 006928_male_Asian_19/mask5.jpg real : 0 predict : 4
# path : 006934_male_Asian_19/incorrect_mask.jpg real : 6 predict : 4
# path : 006941_male_Asian_20/incorrect_mask.jpg real : 6 predict : 12
# path : 006941_male_Asian_20/mask5.jpg real : 0 predict : 12
# path : 006942_male_Asian_19/incorrect_mask.jpg real : 6 predict : 15
# path : 006942_male_Asian_19/mask1.jpg real : 0 predict : 17
# path : 006942_male_Asian_19/mask2.jpg real : 0 predict : 14
# path : 006942_male_Asian_19/mask3.jpg real : 0 predict : 14
# path : 006942_male_Asian_19/mask5.jpg real : 0 predict : 12
# path : 006944_male_Asian_20/incorrect_mask.jpg real : 6 predict : 12
# path : 006944_male_Asian_20/mask1.jpg real : 0 predict : 3
# path : 006944_male_Asian_20/mask3.jpg real : 0 predict : 12
# path : 006944_male_Asian_20/mask4.jpg real : 0 predict : 12
# path : 006944_male_Asian_20/mask5.jpg real : 0 predict : 12
# path : 006945_male_Asian_19/incorrect_mask.jpg real : 6 predict : 12
# path : 006946_male_Asian_20/mask3.jpg real : 0 predict : 14
# path : 006946_male_Asian_20/mask5.jpg real : 0 predict : 12
# path : 006947_male_Asian_19/mask2.jpg real : 0 predict : 3
# path : 006947_male_Asian_19/mask4.jpg real : 0 predict : 3
# path : 006947_male_Asian_19/mask5.jpg real : 0 predict : 3
# path : 006950_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006950_male_Asian_19/mask4.jpg real : 0 predict : 15
# path : 006951_male_Asian_21/incorrect_mask.jpg real : 6 predict : 12
# path : 006952_male_Asian_19/incorrect_mask.jpg real : 6 predict : 14
# path : 006952_male_Asian_19/mask2.jpg real : 0 predict : 8
# path : 006954_male_Asian_19/incorrect_mask.jpg real : 6 predict : 12
# path : 006955_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006956_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006957_male_Asian_20/incorrect_mask.jpg real : 6 predict : 1
# path : 006959_male_Asian_19/incorrect_mask.jpg real : 6 predict : 0
# path : 006959_male_Asian_19/mask1.jpg real : 0 predict : 3
# path : 006959_male_Asian_19/mask3.jpg real : 0 predict : 3
# path : 006959_male_Asian_19/mask4.jpg real : 0 predict : 3

# %%
import matplotlib.pyplot as plt
imgs = submission['ImageID']
label = submission['ans']
fig, axes = plt.subplots(1, 5, sharex=True, sharey=True, figsize=(12, 6))
for i, j in enumerate(range(5)):
    axes[i].imshow(Image.open('/opt/ml/input/data/eval/images/' + imgs[j]))
    axes[i].set_title(f'{label[j]}')
plt.show()
